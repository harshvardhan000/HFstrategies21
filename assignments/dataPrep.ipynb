# %% [markdown]
# <a href="https://colab.research.google.com/github/harshvardhan000/HFstrategies21/blob/main/assignments/dataPrep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download and manipulate data

# %% [markdown]
# This notebook contains information on downloading the Quandl Wiki stock prices and a few other sources that we use throughout the book.

# %% [markdown]
# ## Imports & Settings

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web

pd.set_option('display.expand_frame_repr', False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ahfs_path = Path('/content/drive/MyDrive') 
if not ahfs_path.exists():
    ahfs_path.mkdir()

# %%
# !cd /content/drive/MyDrive/;gdown https://bigdataleitch.s3.amazonaws.com/ahfs-20210622T023207Z-001.zip ;gdown https://bigdataleitch.s3.amazonaws.com/ahfs-20210622T023207Z-002.zip;
# Out:
# Downloading...
# From: https://bigdataleitch.s3.amazonaws.com/ahfs-20210622T023207Z-001.zip
# To: /content/drive/MyDrive/ahfs-20210622T023207Z-001.zip
# 100% 635M/635M [00:14<00:00, 44.0MB/s]
# Downloading...
# From: https://bigdataleitch.s3.amazonaws.com/ahfs-20210622T023207Z-002.zip
# To: /content/drive/My Drive/ahfs-20210622T023207Z-002.zip
# 100% 759M/759M [00:19<00:00, 38.9MB/s]

# %%
# !unzip /content/drive/MyDrive/ahfs-20210622T023207Z-001.zip -d /content/drive/MyDrive;
# !unzip /content/drive/MyDrive/ahfs-20210622T023207Z-002.zip -d /content/drive/MyDrive;
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bhfao.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bkcc.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/benew.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bhfap.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bfiiw.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bkng.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bhfal.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/biol.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bhat.us.txt
#   inflating: /content/drive/MyDrive/ahfs/stooq/data/daily/us/nasdaq stocks/1/bfc.us.txt
# ...
